# %%
# !pip install ./cacheflow-0.1.0-py3-none-any.whl
# Out:
# Processing ./cacheflow-0.1.0-py3-none-any.whl
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from cacheflow==0.1.0) (2.10.0+cu128)
# Requirement already satisfied: safetensors>=0.4 in /usr/local/lib/python3.12/dist-packages (from cacheflow==0.1.0) (0.7.0)
# Collecting huggingface-hub>=1.10.2 (from cacheflow==0.1.0)
#   Downloading huggingface_hub-1.11.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.10.2->cacheflow==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->cacheflow==0.1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1->cacheflow==0.1.0) (1.5.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.2->cacheflow==0.1.0) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.2->cacheflow==0.1.0) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.2->cacheflow==0.1.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.2->cacheflow==0.1.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=1.10.2->cacheflow==0.1.0) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->cacheflow==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->cacheflow==0.1.0) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=1.10.2->cacheflow==0.1.0) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=1.10.2->cacheflow==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=1.10.2->cacheflow==0.1.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=1.10.2->cacheflow==0.1.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=1.10.2->cacheflow==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=1.10.2->cacheflow==0.1.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=1.10.2->cacheflow==0.1.0) (0.1.2)
# Downloading huggingface_hub-1.11.0-py3-none-any.whl (645 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.5/645.5 kB 31.0 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, cacheflow
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.10.1
#     Uninstalling huggingface_hub-1.10.1:
#       Successfully uninstalled huggingface_hub-1.10.1
# Successfully installed cacheflow-0.1.0 huggingface-hub-1.11.0

# %%
from huggingface_hub import snapshot_download

model_name = "jetmoe/jetmoe-8b"
model_path = "./weights/granite/"

snapshot_download(model_name, local_dir=model_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# '/content/weights/granite'

# %%
import os
import json
from safetensors import safe_open
from safetensors.torch import save_file


def separate_safetensors_smart(input_path, output_directory):
    # 1. Create the output directory
    os.makedirs(output_directory, exist_ok=True)

    new_weight_map = {}
    total_size = 0
    files_to_process = []
    input_dir = os.path.dirname(input_path)

    # 2. Figure out if the input is a single file or an index.json
    if input_path.endswith(".json"):
        print(f"Detected index JSON. Reading {input_path}...")
        with open(input_path, "r") as f:
            index_data = json.load(f)

        # Look at the old weight map to find out what shard files exist
        old_weight_map = index_data.get("weight_map", {})

        # Get a list of unique shard files (e.g. model-00001-of-00003.safetensors)
        unique_shards = set(old_weight_map.values())

        # Build the full paths to those shards
        for shard in unique_shards:
            shard_path = os.path.join(input_dir, shard) if input_dir else shard
            files_to_process.append(shard_path)

        print(f"Found {len(files_to_process)} shard file(s) to unpack.")

    elif input_path.endswith(".safetensors"):
        print(f"Detected single safetensors file: {input_path}")
        files_to_process = [input_path]
    else:
        raise ValueError("Input file must be a .safetensors or .index.json file")

    # 3. Process every file we found
    tensor_count = 0

    for file_path in files_to_process:
        print(f"\nOpening {os.path.basename(file_path)}...")

        # Open lazily
        with safe_open(file_path, framework="pt", device="cpu") as f:
            keys = f.keys()
            for key in keys:
                tensor_count += 1

                # Extract only this specific layer into RAM
                tensor = f.get_tensor(key)

                # Create exact filename for this layer
                filename = f"{key}.safetensors"
                output_path = os.path.join(output_directory, filename)

                # Save it to the new folder
                save_file({key: tensor}, output_path)

                # Track size and map it for the new index
                file_size = os.path.getsize(output_path)
                total_size += file_size
                new_weight_map[key] = filename

                print(f"  Saved: {filename}")

    # 4. Generate the NEW model.safetensors.index.json
    print("\nAll layers separated. Generating new model.safetensors.index.json...")

    new_index_data = {
        "metadata": {"total_size": total_size},
        "weight_map": new_weight_map,
    }

    index_out_path = os.path.join(output_directory, "model.safetensors.index.json")

    with open(index_out_path, "w") as index_file:
        json.dump(new_index_data, index_file, indent=2)

    print(f"\n--- SUCCESS ---")
    print(f"Total separate tensors saved: {tensor_count}")
    print(f"Total model size: {total_size / (1024**3):.2f} GB")
    print(f"New index saved to: {index_out_path}")


# ==========================================
# CONFIGURATION - CHANGE THESE PATHS
# ==========================================

# Scenario A: Point this to a single large file
# INPUT_PATH = "model.safetensors"

# Scenario B: Point this to an existing index file
INPUT_PATH = "./weights/granite/model.safetensors.index.json"

# The folder where all the tiny files and the new index will be created
OUTPUT_DIR = "./weights/granite/"

separate_safetensors_smart(INPUT_PATH, OUTPUT_DIR)
# Out:
# Detected index JSON. Reading ./weights/granite/model.safetensors.index.json...
# Found 4 shard file(s) to unpack.
#
# Opening model-00002-of-00004.safetensors...
#   Saved: model.layers.10.input_layernorm.weight.safetensors
#   Saved: model.layers.10.mlp.bias.safetensors
#   Saved: model.layers.10.mlp.input_linear.weight.safetensors
#   Saved: model.layers.10.mlp.output_linear.weight.safetensors
#   Saved: model.layers.10.mlp.router.layer.weight.safetensors
#   Saved: model.layers.10.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.10.self_attention.experts.bias.safetensors
#   Saved: model.layers.10.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.10.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.10.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.10.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.11.input_layernorm.weight.safetensors
#   Saved: model.layers.11.mlp.bias.safetensors
#   Saved: model.layers.11.mlp.input_linear.weight.safetensors
#   Saved: model.layers.11.mlp.output_linear.weight.safetensors
#   Saved: model.layers.11.mlp.router.layer.weight.safetensors
#   Saved: model.layers.11.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.11.self_attention.experts.bias.safetensors
#   Saved: model.layers.11.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.11.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.11.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.11.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.12.input_layernorm.weight.safetensors
#   Saved: model.layers.12.mlp.bias.safetensors
#   Saved: model.layers.12.mlp.input_linear.weight.safetensors
#   Saved: model.layers.12.mlp.output_linear.weight.safetensors
#   Saved: model.layers.12.mlp.router.layer.weight.safetensors
#   Saved: model.layers.12.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.12.self_attention.experts.bias.safetensors
#   Saved: model.layers.12.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.12.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.12.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.12.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.13.input_layernorm.weight.safetensors
#   Saved: model.layers.13.mlp.bias.safetensors
#   Saved: model.layers.13.mlp.input_linear.weight.safetensors
#   Saved: model.layers.13.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.13.self_attention.experts.bias.safetensors
#   Saved: model.layers.13.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.13.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.13.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.13.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.6.mlp.output_linear.weight.safetensors
#   Saved: model.layers.6.mlp.router.layer.weight.safetensors
#   Saved: model.layers.7.input_layernorm.weight.safetensors
#   Saved: model.layers.7.mlp.bias.safetensors
#   Saved: model.layers.7.mlp.input_linear.weight.safetensors
#   Saved: model.layers.7.mlp.output_linear.weight.safetensors
#   Saved: model.layers.7.mlp.router.layer.weight.safetensors
#   Saved: model.layers.7.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.7.self_attention.experts.bias.safetensors
#   Saved: model.layers.7.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.7.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.7.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.7.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.8.input_layernorm.weight.safetensors
#   Saved: model.layers.8.mlp.bias.safetensors
#   Saved: model.layers.8.mlp.input_linear.weight.safetensors
#   Saved: model.layers.8.mlp.output_linear.weight.safetensors
#   Saved: model.layers.8.mlp.router.layer.weight.safetensors
#   Saved: model.layers.8.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.8.self_attention.experts.bias.safetensors
#   Saved: model.layers.8.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.8.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.8.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.8.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.9.input_layernorm.weight.safetensors
#   Saved: model.layers.9.mlp.bias.safetensors
#   Saved: model.layers.9.mlp.input_linear.weight.safetensors
#   Saved: model.layers.9.mlp.output_linear.weight.safetensors
#   Saved: model.layers.9.mlp.router.layer.weight.safetensors
#   Saved: model.layers.9.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.9.self_attention.experts.bias.safetensors
#   Saved: model.layers.9.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.9.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.9.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.9.self_attention.kv_proj.weight.safetensors
#
# Opening model-00003-of-00004.safetensors...
#   Saved: model.layers.13.mlp.output_linear.weight.safetensors
#   Saved: model.layers.13.mlp.router.layer.weight.safetensors
#   Saved: model.layers.14.input_layernorm.weight.safetensors
#   Saved: model.layers.14.mlp.bias.safetensors
#   Saved: model.layers.14.mlp.input_linear.weight.safetensors
#   Saved: model.layers.14.mlp.output_linear.weight.safetensors
#   Saved: model.layers.14.mlp.router.layer.weight.safetensors
#   Saved: model.layers.14.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.14.self_attention.experts.bias.safetensors
#   Saved: model.layers.14.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.14.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.14.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.14.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.15.input_layernorm.weight.safetensors
#   Saved: model.layers.15.mlp.bias.safetensors
#   Saved: model.layers.15.mlp.input_linear.weight.safetensors
#   Saved: model.layers.15.mlp.output_linear.weight.safetensors
#   Saved: model.layers.15.mlp.router.layer.weight.safetensors
#   Saved: model.layers.15.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.15.self_attention.experts.bias.safetensors
#   Saved: model.layers.15.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.15.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.15.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.15.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.16.input_layernorm.weight.safetensors
#   Saved: model.layers.16.mlp.bias.safetensors
#   Saved: model.layers.16.mlp.input_linear.weight.safetensors
#   Saved: model.layers.16.mlp.output_linear.weight.safetensors
#   Saved: model.layers.16.mlp.router.layer.weight.safetensors
#   Saved: model.layers.16.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.16.self_attention.experts.bias.safetensors
#   Saved: model.layers.16.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.16.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.16.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.16.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.17.input_layernorm.weight.safetensors
#   Saved: model.layers.17.mlp.bias.safetensors
#   Saved: model.layers.17.mlp.input_linear.weight.safetensors
#   Saved: model.layers.17.mlp.output_linear.weight.safetensors
#   Saved: model.layers.17.mlp.router.layer.weight.safetensors
#   Saved: model.layers.17.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.17.self_attention.experts.bias.safetensors
#   Saved: model.layers.17.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.17.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.17.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.17.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.18.input_layernorm.weight.safetensors
#   Saved: model.layers.18.mlp.bias.safetensors
#   Saved: model.layers.18.mlp.input_linear.weight.safetensors
#   Saved: model.layers.18.mlp.output_linear.weight.safetensors
#   Saved: model.layers.18.mlp.router.layer.weight.safetensors
#   Saved: model.layers.18.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.18.self_attention.experts.bias.safetensors
#   Saved: model.layers.18.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.18.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.18.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.18.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.19.input_layernorm.weight.safetensors
#   Saved: model.layers.19.mlp.bias.safetensors
#   Saved: model.layers.19.mlp.input_linear.weight.safetensors
#   Saved: model.layers.19.mlp.output_linear.weight.safetensors
#   Saved: model.layers.19.mlp.router.layer.weight.safetensors
#   Saved: model.layers.19.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.19.self_attention.experts.bias.safetensors
#   Saved: model.layers.19.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.19.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.19.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.19.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.20.input_layernorm.weight.safetensors
#   Saved: model.layers.20.mlp.bias.safetensors
#   Saved: model.layers.20.mlp.input_linear.weight.safetensors
#   Saved: model.layers.20.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.20.self_attention.experts.bias.safetensors
#   Saved: model.layers.20.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.20.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.20.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.20.self_attention.kv_proj.weight.safetensors
#
# Opening model-00004-of-00004.safetensors...
#   Saved: model.layers.20.mlp.output_linear.weight.safetensors
#   Saved: model.layers.20.mlp.router.layer.weight.safetensors
#   Saved: model.layers.21.input_layernorm.weight.safetensors
#   Saved: model.layers.21.mlp.bias.safetensors
#   Saved: model.layers.21.mlp.input_linear.weight.safetensors
#   Saved: model.layers.21.mlp.output_linear.weight.safetensors
#   Saved: model.layers.21.mlp.router.layer.weight.safetensors
#   Saved: model.layers.21.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.21.self_attention.experts.bias.safetensors
#   Saved: model.layers.21.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.21.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.21.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.21.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.22.input_layernorm.weight.safetensors
#   Saved: model.layers.22.mlp.bias.safetensors
#   Saved: model.layers.22.mlp.input_linear.weight.safetensors
#   Saved: model.layers.22.mlp.output_linear.weight.safetensors
#   Saved: model.layers.22.mlp.router.layer.weight.safetensors
#   Saved: model.layers.22.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.22.self_attention.experts.bias.safetensors
#   Saved: model.layers.22.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.22.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.22.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.22.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.23.input_layernorm.weight.safetensors
#   Saved: model.layers.23.mlp.bias.safetensors
#   Saved: model.layers.23.mlp.input_linear.weight.safetensors
#   Saved: model.layers.23.mlp.output_linear.weight.safetensors
#   Saved: model.layers.23.mlp.router.layer.weight.safetensors
#   Saved: model.layers.23.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.23.self_attention.experts.bias.safetensors
#   Saved: model.layers.23.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.23.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.23.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.23.self_attention.kv_proj.weight.safetensors
#   Saved: model.norm.weight.safetensors
#
# Opening model-00001-of-00004.safetensors...
#   Saved: model.embed_tokens.weight.safetensors
#   Saved: model.layers.0.input_layernorm.weight.safetensors
#   Saved: model.layers.0.mlp.bias.safetensors
#   Saved: model.layers.0.mlp.input_linear.weight.safetensors
#   Saved: model.layers.0.mlp.output_linear.weight.safetensors
#   Saved: model.layers.0.mlp.router.layer.weight.safetensors
#   Saved: model.layers.0.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.0.self_attention.experts.bias.safetensors
#   Saved: model.layers.0.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.0.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.0.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.0.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.1.input_layernorm.weight.safetensors
#   Saved: model.layers.1.mlp.bias.safetensors
#   Saved: model.layers.1.mlp.input_linear.weight.safetensors
#   Saved: model.layers.1.mlp.output_linear.weight.safetensors
#   Saved: model.layers.1.mlp.router.layer.weight.safetensors
#   Saved: model.layers.1.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.1.self_attention.experts.bias.safetensors
#   Saved: model.layers.1.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.1.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.1.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.1.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.2.input_layernorm.weight.safetensors
#   Saved: model.layers.2.mlp.bias.safetensors
#   Saved: model.layers.2.mlp.input_linear.weight.safetensors
#   Saved: model.layers.2.mlp.output_linear.weight.safetensors
#   Saved: model.layers.2.mlp.router.layer.weight.safetensors
#   Saved: model.layers.2.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.2.self_attention.experts.bias.safetensors
#   Saved: model.layers.2.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.2.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.2.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.2.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.3.input_layernorm.weight.safetensors
#   Saved: model.layers.3.mlp.bias.safetensors
#   Saved: model.layers.3.mlp.input_linear.weight.safetensors
#   Saved: model.layers.3.mlp.output_linear.weight.safetensors
#   Saved: model.layers.3.mlp.router.layer.weight.safetensors
#   Saved: model.layers.3.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.3.self_attention.experts.bias.safetensors
#   Saved: model.layers.3.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.3.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.3.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.3.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.4.input_layernorm.weight.safetensors
#   Saved: model.layers.4.mlp.bias.safetensors
#   Saved: model.layers.4.mlp.input_linear.weight.safetensors
#   Saved: model.layers.4.mlp.output_linear.weight.safetensors
#   Saved: model.layers.4.mlp.router.layer.weight.safetensors
#   Saved: model.layers.4.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.4.self_attention.experts.bias.safetensors
#   Saved: model.layers.4.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.4.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.4.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.4.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.5.input_layernorm.weight.safetensors
#   Saved: model.layers.5.mlp.bias.safetensors
#   Saved: model.layers.5.mlp.input_linear.weight.safetensors
#   Saved: model.layers.5.mlp.output_linear.weight.safetensors
#   Saved: model.layers.5.mlp.router.layer.weight.safetensors
#   Saved: model.layers.5.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.5.self_attention.experts.bias.safetensors
#   Saved: model.layers.5.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.5.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.5.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.5.self_attention.kv_proj.weight.safetensors
#   Saved: model.layers.6.input_layernorm.weight.safetensors
#   Saved: model.layers.6.mlp.bias.safetensors
#   Saved: model.layers.6.mlp.input_linear.weight.safetensors
#   Saved: model.layers.6.post_attention_layernorm.weight.safetensors
#   Saved: model.layers.6.self_attention.experts.bias.safetensors
#   Saved: model.layers.6.self_attention.experts.input_linear.weight.safetensors
#   Saved: model.layers.6.self_attention.experts.output_linear.weight.safetensors
#   Saved: model.layers.6.self_attention.experts.router.layer.weight.safetensors
#   Saved: model.layers.6.self_attention.kv_proj.weight.safetensors
#
# All layers separated. Generating new model.safetensors.index.json...
#
# --- SUCCESS ---
# Total separate tensors saved: 266
# Total model size: 15.87 GB
# New index saved to: ./weights/granite/model.safetensors.index.json

# %%
from transformers import AutoTokenizer
import torch
from cacheflow import initialize_model


model_path = "./weights/granite/"
loaded = initialize_model(model_path)
print(loaded.device, loaded.dtype)


tokenizer = AutoTokenizer.from_pretrained(model_path)
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = loaded.config.pad_token_id
# Out:
# cuda torch.float16

# %%
torch.cuda.reset_peak_memory_stats()
question = "What is the capital of Bangladesh?"
prompt = f"Question: {question}\nAnswer:"
# prompt = f"write 10 line poem about python language"

result = loaded.generate_text(
    tokenizer=tokenizer,
    prompt=prompt,
    max_new_tokens=10,
    min_new_tokens=8,
    temperature=0.5,
    top_k=10,
    eos_token_id=loaded.config.eos_token_id,
    repetition_penalty=1.15,
    block_special_tokens=True,
    return_raw=True,
)

print("generated_token_ids:", result["token_ids"])
print("decoded_raw:", repr(result["raw_text"]))
print("decoded:", repr(result["text"]))
# Out:
# generated_token_ids: [28757, 28716, 8389, 13, 24994, 28747, 1824, 349, 272, 7639]
# decoded_raw: 'Dhaka\nQuestion: What is the largest'
# decoded: 'Dhaka\nQuestion: What is the largest'

# %%
print(
    "after warmup alloc/res:",
    torch.cuda.memory_allocated() / 1e9,
    torch.cuda.memory_reserved() / 1e9,
)
print("peak alloc:", torch.cuda.max_memory_allocated() / 1e9)
if torch.cuda.is_available():
    peak_mem = torch.cuda.max_memory_allocated() / (1024**2)
    curr_mem = torch.cuda.memory_allocated() / (1024**2)
    print(f"🔥 Peak VRAM Allocated:   {peak_mem:.2f} MB")
    print(f"   Current VRAM Allocated: {curr_mem:.2f} MB")
# Out:
# after warmup alloc/res: 4.67350784 10.913579008
# peak alloc: 5.00127488
# 🔥 Peak VRAM Allocated:   4769.59 MB
#    Current VRAM Allocated: 4457.00 MB
